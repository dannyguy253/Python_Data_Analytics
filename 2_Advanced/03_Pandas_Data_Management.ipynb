# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/2_Advanced/03_Pandas_Data_Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Pandas Data Management

# %% [markdown]
# Load data.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# DataFrame Copy
df_original = df.copy()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# ## Copy

# %% [markdown]
# Recall from the last lesson, when we filled in missing values for median salary.
#
# Here let's make a new dataframe `df_altered` and only make changes to it.

# %%
# Create new dataframe
df_altered = df_original

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Let's fill in missing values with the median value.

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %% [markdown]
# Now let's inspect the altered DataFrame.

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# That was good...
#
# But what about the original...

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Holdup!! How the heck did `df_original` get altered!?!

# %% [markdown]
# Well both the variables of `df_original` and `df_altered` are referencing the same DataFrame.

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2984568468688
# ID of df_altered:                 2984568468688
# Are the two dataframes the same?  True

# %% [markdown]
# Instead we can use the .copy() method
#
# - `copy()`: Copy a DataFrame.

# %%
df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2984565379856
# ID of df_altered:                 2984480641360
# Are the two dataframes the same?  False

# %% [markdown]
# Now when we do this same operation:

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# The original dataframe doesn't get altered!

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Now that we've created a copy of our data, we want to start our analysis. But if we have a large set of data we only want to take a subset of data to make it more manageable. We can use `sample()` to get a random sample of the data.

# %% [markdown]
# ## Sample
#
# ### Notes
#
# * `sample()`: Random sample of items.
#
# ### Examples
#
# Let's get a random sample of the data. You could get a sample with a fixed row number.

# %%
df.sample(n=5)
# Out:
#           job_title_short                                   job_title  \
# 164486      Data Engineer                         Azure data-engineer
# 524078       Data Analyst  Data Analyst, Cell Materials Manufacturing
# 281603  Software Engineer                         Python/API Engineer
# 165706       Data Analyst            Data Analyst at Old Mutual Kenya
# 228629     Data Scientist                 Evaluation & Data Scientist
#
#                   job_location                job_via job_schedule_type  \
# 164486  Amsterdam, Netherlands           via LinkedIn         Full-time
# 524078              Sparks, NV           via LinkedIn         Full-time
# 281603            Tokyo, Japan  via EFinancialCareers         Full-time
# 165706          Nairobi, Kenya        via BeBee Kenya         Full-time
# 228629              Norman, OK     via Higher Ed Jobs         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 164486               False                Netherlands 2023-07-03 15:15:32
# 524078               False  California, United States 2023-06-08 11:00:37
# 281603               False                      Japan 2023-06-01 07:59:23
# 165706               False                      Kenya 2023-12-27 15:17:50
# 228629               False       Texas, United States 2023-11-21 07:04:02
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 164486                   True                 False    Netherlands
# 524078                  False                  True  United States
# 281603                   True                 False          Japan
# 165706                  False                 False          Kenya
# 228629                  False                 False  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 164486         NaN              NaN              NaN
# 524078         NaN              NaN              NaN
# 281603         NaN              NaN              NaN
# 165706         NaN              NaN              NaN
# 228629         NaN              NaN              NaN
#
#                          company_name  \
# 164486  Autoriteit Financiële Markten
# 524078                          Tesla
# 281603              Robert Half Japan
# 165706               Old Mutual Kenya
# 228629         University of Oklahoma
#
#                                                job_skills  \
# 164486               ['sql', 'c#', 'powershell', 'azure']
# 524078  ['sql', 'python', 'spark', 'hadoop', 'tableau'...
# 281603  ['python', 'c#', 'aws', 'gcp', 'express', 'doc...
# 165706  ['sql', 'python', 'r', 'shell', 'aws', 'azure'...
# 228629                                                NaN
#
#                                           job_type_skills
# 164486  {'cloud': ['azure'], 'programming': ['sql', 'c...
# 524078  {'analyst_tools': ['tableau'], 'async': ['jira...
# 281603  {'cloud': ['aws', 'gcp'], 'other': ['docker', ...
# 165706  {'analyst_tools': ['power bi', 'tableau', 'exc...
# 228629                                                NaN

# %% [markdown]
# Or you can randomly select a fraction of the data (e.g., 10% of the rows), with or without replacement.

# %%
df.sample(frac=0.1, replace=False)
# Out:
#        job_title_short                                          job_title  \
# 430849    Data Analyst                        Alternance Data Analyst H/F
# 70879     Data Analyst                                       Data Analyst
# 229244    Data Analyst                            Data Scientists Analyst
# 442755   Data Engineer  GCP Data Engineer-Pune(Hybrid)-8+years-Immedia...
# 594116    Data Analyst                        Junior Analyst Medical Data
# ...                ...                                                ...
# 198895    Data Analyst                                       Data Analyst
# 117246    Data Analyst                      Junior Financial Data Analyst
# 110093    Data Analyst                       Clinical Statistical Analyst
# 450561  Data Scientist                    Software Engineer, Data Science
# 29523    Data Engineer               Lead Data Engineer - NFT Marketplace
#
#               job_location            job_via job_schedule_type  \
# 430849  Versailles, France          via BeBee         Full-time
# 70879     San Ġwann, Malta          via Melga         Full-time
# 229244     Gainesville, FL    via Trabajo.org         Full-time
# 442755  Maharashtra, India          via Shine         Full-time
# 594116      Washington, DC    via Trabajo.org         Full-time
# ...                    ...                ...               ...
# 198895       Deerfield, IL    via Trabajo.org         Full-time
# 117246           Tampa, FL          via BeBee         Full-time
# 110093       Cork, Ireland  via BeBee Ireland         Full-time
# 450561      Washington, DC          via BeBee         Full-time
# 29523             Anywhere       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 430849               False                   France 2023-03-16 16:47:05
# 70879                False                    Malta 2023-02-28 00:44:54
# 229244               False   Florida, United States 2023-11-10 07:21:53
# 442755               False                    India 2023-11-15 16:13:51
# 594116               False  New York, United States 2023-11-28 09:00:20
# ...                    ...                      ...                 ...
# 198895               False  Illinois, United States 2023-05-02 15:02:54
# 117246               False   Florida, United States 2023-05-26 08:02:28
# 110093               False                  Ireland 2023-07-17 00:28:48
# 450561               False                  Georgia 2023-10-18 14:45:18
# 29523                 True   Florida, United States 2023-03-23 13:17:29
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 430849                  False                 False         France
# 70879                    True                 False          Malta
# 229244                  False                 False  United States
# 442755                   True                 False          India
# 594116                  False                 False  United States
# ...                       ...                   ...            ...
# 198895                  False                 False  United States
# 117246                  False                  True  United States
# 110093                  False                 False        Ireland
# 450561                  False                  True  United States
# 29523                    True                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 430849         NaN              NaN              NaN
# 70879          NaN              NaN              NaN
# 229244         NaN              NaN              NaN
# 442755         NaN              NaN              NaN
# 594116         NaN              NaN              NaN
# ...            ...              ...              ...
# 198895         NaN              NaN              NaN
# 117246         NaN              NaN              NaN
# 110093         NaN              NaN              NaN
# 450561         NaN              NaN              NaN
# 29523         year         187500.0              NaN
#
#                                  company_name  \
# 430849  Bouygues Bâtiment Ile de France Siège
# 70879                          Hornetsecurity
# 229244                          CareerBuilder
# 442755                                    EXL
# 594116                        CGI Group, Inc.
# ...                                       ...
# 198895                                  eTeam
# 117246                                 Humana
# 110093                                  Lilly
# 450561                                 BOEING
# 29523                              Intelletec
#
#                                                job_skills  \
# 430849            ['sql', 'snowflake', 'power bi', 'sap']
# 70879                     ['sql', 'r', 'python', 'excel']
# 229244                               ['c', 'r', 'python']
# 442755              ['python', 'gcp', 'spark', 'pyspark']
# 594116                                              ['c']
# ...                                                   ...
# 198895  ['sql', 'tableau', 'visio', 'word', 'powerpoin...
# 117246                       ['sql', 'excel', 'power bi']
# 110093                                                NaN
# 450561  ['python', 'pytorch', 'tensorflow', 'scikit-le...
# 29523                        ['python', 'spark', 'kafka']
#
#                                           job_type_skills
# 430849  {'analyst_tools': ['power bi', 'sap'], 'cloud'...
# 70879   {'analyst_tools': ['excel'], 'programming': ['...
# 229244              {'programming': ['c', 'r', 'python']}
# 442755  {'cloud': ['gcp'], 'libraries': ['spark', 'pys...
# 594116                             {'programming': ['c']}
# ...                                                   ...
# 198895  {'analyst_tools': ['tableau', 'visio', 'word',...
# 117246  {'analyst_tools': ['excel', 'power bi'], 'prog...
# 110093                                                NaN
# 450561  {'libraries': ['pytorch', 'tensorflow', 'sciki...
# 29523   {'libraries': ['spark', 'kafka'], 'programming...
#
# [78574 rows x 17 columns]

# %% [markdown]
# Now you can analyze these subsets of data.
