# %% [markdown]
# # How are in-demand skills trending for Data Engineers?
#
# ### Methodology
#
# 1. Aggregate skill counts monthly
# 2. Re-analyze based on percentage of total jobs
# 3. Plot the monthly skill demand

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  
import seaborn as sns

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df_DE_US = df[(df['job_title_short'] == 'Data Engineer') & (df['job_country'] == 'United States')]

# %%
df_DE_US['job_posted_month_no'] = df_DE_US['job_posted_date'].dt.month

# %%
df_DE_US_explode = df_DE_US.explode('job_skills')

# %%
df_DE_US_pivot = df_DE_US_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value = 0)
df_DE_US_pivot.loc['Total'] = df_DE_US_pivot.sum()
df_DE_US_pivot = df_DE_US_pivot[df_DE_US_pivot.loc['Total'].sort_values(ascending=False).index]
df_DE_US_pivot = df_DE_US_pivot.drop('Total')
df_DE_US_pivot
# Out:
# job_skills            sql  python   aws  azure  spark  java  snowflake  \
# job_posted_month_no
# 1                    1826    1745  1119    841    916   695        592
# 2                    2109    2043  1415    965   1063   829        763
# 3                    2204    2126  1472   1023   1038   791        704
# 4                    1914    1868  1222    937    878   682        676
# 5                    2077    2023  1252    990    952   730        681
# 6                    2048    1882  1260    947    955   686        668
# 7                    1789    1689  1166    794    821   615        624
# 8                    2246    2155  1388   1003   1006   754        749
# 9                    2090    1934  1267    960    941   671        700
# 10                   1944    1864  1192   1037    898   643        669
# 11                   1896    1770  1202    930    935   624        736
# 12                   1815    1663  1063    894    839   641        628
#
# job_skills           hadoop  kafka  scala  ...  lisp  fastify  qt  powerbi  \
# job_posted_month_no                        ...
# 1                       515    547    517  ...     0        0   0        0
# 2                       645    647    597  ...     1        0   0        0
# 3                       640    605    587  ...     0        0   0        0
# 4                       498    514    534  ...     0        0   0        0
# 5                       529    491    509  ...     0        0   0        0
# 6                       516    495    459  ...     0        0   0        0
# 7                       483    448    461  ...     1        0   1        0
# 8                       594    565    557  ...     0        0   0        0
# 9                       479    500    483  ...     0        0   0        1
# 10                      468    431    471  ...     0        0   0        0
# 11                      502    489    449  ...     0        0   0        0
# 12                      471    497    503  ...     0        1   0        0
#
# job_skills           mlpack  sqlserver  svelte  workfront  xamarin  wrike
# job_posted_month_no
# 1                         0          0       0          0        0      0
# 2                         0          0       0          0        0      0
# 3                         0          0       0          0        0      0
# 4                         0          0       0          0        0      0
# 5                         0          0       0          0        1      0
# 6                         0          0       0          0        0      0
# 7                         0          0       0          1        0      0
# 8                         0          1       1          0        0      0
# 9                         0          0       0          0        0      0
# 10                        1          0       0          0        0      0
# 11                        0          0       0          0        0      0
# 12                        0          0       0          0        0      1
#
# [12 rows x 222 columns]

# %%
DE_totals = df_DE_US.groupby('job_posted_month_no').size()

# %%
df_DE_US_percent = df_DE_US_pivot.div(DE_totals/100, axis=0)

# %%
# change month number to month name
df_DE_US_percent = df_DE_US_percent.reset_index()
df_DE_US_percent['job_posted_month'] = df_DE_US_percent['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DE_US_percent = df_DE_US_percent.set_index('job_posted_month')
df_DE_US_percent = df_DE_US_percent.drop(columns='job_posted_month_no')

df_DE_US_percent
# Out:
# job_skills              sql     python        aws      azure      spark  \
# job_posted_month
# Jan               68.775895  65.725047  42.146893  31.676083  34.500942
# Feb               68.921569  66.764706  46.241830  31.535948  34.738562
# Mar               69.242853  66.792334  46.245680  32.139491  32.610745
# Apr               68.332738  66.690468  43.627276  33.452338  31.345948
# May               69.791667  67.977151  42.069892  33.266129  31.989247
# Jun               70.791566  65.053578  43.553405  32.734186  33.010716
# Jul               69.610895  65.719844  45.369650  30.894942  31.945525
# Aug               68.706026  65.922300  42.459468  30.682166  30.773937
# Sep               64.826303  59.987593  39.299007  29.776675  29.187345
# Oct               64.477612  61.824212  39.535655  34.394693  29.784411
# Nov               67.883996  63.372718  43.036162  33.297530  33.476549
# Dec               68.723968  62.968573  40.249905  33.850814  31.768270
#
# job_skills             java  snowflake     hadoop      kafka      scala  ...  \
# job_posted_month                                                         ...
# Jan               26.177024  22.297552  19.397363  20.602637  19.472693  ...
# Feb               27.091503  24.934641  21.078431  21.143791  19.509804  ...
# Mar               24.850770  22.117499  20.106817  19.007226  18.441722  ...
# Apr               24.348447  24.134238  17.779365  18.350589  19.064620  ...
# May               24.529570  22.883065  17.775538  16.498656  17.103495  ...
# Jun               23.712409  23.090218  17.836156  17.110266  15.865883  ...
# Jul               23.929961  24.280156  18.793774  17.431907  17.937743  ...
# Aug               23.065158  22.912206  18.170694  17.283573  17.038850  ...
# Sep               20.812655  21.712159  14.857320  15.508685  14.981390  ...
# Oct               21.326700  22.189055  15.522388  14.295191  15.621891  ...
# Nov               22.341568  26.351593  17.973505  17.508056  16.075904  ...
# Dec               24.271109  23.778872  17.834154  18.818629  19.045816  ...
#
# job_skills            lisp   fastify        qt   powerbi    mlpack  sqlserver  \
# job_posted_month
# Jan               0.000000  0.000000  0.000000  0.000000  0.000000    0.00000
# Feb               0.032680  0.000000  0.000000  0.000000  0.000000    0.00000
# Mar               0.000000  0.000000  0.000000  0.000000  0.000000    0.00000
# Apr               0.000000  0.000000  0.000000  0.000000  0.000000    0.00000
# May               0.000000  0.000000  0.000000  0.000000  0.000000    0.00000
# Jun               0.000000  0.000000  0.000000  0.000000  0.000000    0.00000
# Jul               0.038911  0.000000  0.038911  0.000000  0.000000    0.00000
# Aug               0.000000  0.000000  0.000000  0.000000  0.000000    0.03059
# Sep               0.000000  0.000000  0.000000  0.031017  0.000000    0.00000
# Oct               0.000000  0.000000  0.000000  0.000000  0.033167    0.00000
# Nov               0.000000  0.000000  0.000000  0.000000  0.000000    0.00000
# Dec               0.000000  0.037864  0.000000  0.000000  0.000000    0.00000
#
# job_skills         svelte  workfront   xamarin     wrike
# job_posted_month
# Jan               0.00000   0.000000  0.000000  0.000000
# Feb               0.00000   0.000000  0.000000  0.000000
# Mar               0.00000   0.000000  0.000000  0.000000
# Apr               0.00000   0.000000  0.000000  0.000000
# May               0.00000   0.000000  0.033602  0.000000
# Jun               0.00000   0.000000  0.000000  0.000000
# Jul               0.00000   0.038911  0.000000  0.000000
# Aug               0.03059   0.000000  0.000000  0.000000
# Sep               0.00000   0.000000  0.000000  0.000000
# Oct               0.00000   0.000000  0.000000  0.000000
# Nov               0.00000   0.000000  0.000000  0.000000
# Dec               0.00000   0.000000  0.000000  0.037864
#
# [12 rows x 222 columns]

# %%
from matplotlib.ticker import PercentFormatter

df_plot = df_DE_US_percent.iloc[:, :5]

sns.lineplot(data=df_plot, dashes=False, palette='tab10')
sns.set_theme(style='ticks')
sns.despine()

plt.title('Trending Top Skills for Data Engineers in the US')
plt.ylabel('Likelihood in Job Posting')
plt.xlabel('2023')
plt.legend().remove()



ax=plt.gca()
ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))



for i in range(5):
    plt.text(11.2, df_plot.iloc[-1, i], df_plot.columns[i])

plt.show()
